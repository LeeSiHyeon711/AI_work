# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np

# %%
torch.manual_seed(1)
x_data = torch.FloatTensor([[1],[2],[3],[4],[5]])
y_data = torch.FloatTensor([[3],[5],[7],[9],[11]])

# %%
class LinearRegressionModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear=nn.Linear(1,1)

    def forward(self, x):
        return self.linear(x)

# %%
# 모델 만들기
model = LinearRegressionModel()
print(model)

optimizer = optim.SGD(model.parameters(), lr=0.01)
# Out:
# LinearRegressionModel(
#   (linear): Linear(in_features=1, out_features=1, bias=True)
# )

# %%
# 수행
epochs = 2001

for epoch in range(epochs):
    y = model(x_data)
    cost = F.mse_loss(y, x_data)

    optimizer.zero_grad()
    cost.backward()
    optimizer.step()

    if epoch%100 == 0:
        print(f"epoch: {epoch}, cost: {cost.item()}, mocdel: {model.parameters()}")
# Out:
# epoch: 0, cost: 4.063195705413818, mocdel: <generator object Module.parameters at 0x0000025F868718C0>
# epoch: 100, cost: 0.007522144820541143, mocdel: <generator object Module.parameters at 0x0000025FF2B9C900>
# epoch: 200, cost: 0.003821000922471285, mocdel: <generator object Module.parameters at 0x0000025FF2B9C900>
# epoch: 300, cost: 0.001940945745445788, mocdel: <generator object Module.parameters at 0x0000025FF2B9C900>
# epoch: 400, cost: 0.000985942198894918, mocdel: <generator object Module.parameters at 0x0000025FF2B9C900>
# epoch: 500, cost: 0.0005008282023482025, mocdel: <generator object Module.parameters at 0x0000025FF2B9C900>
# epoch: 600, cost: 0.0002544031012803316, mocdel: <generator object Module.parameters at 0x0000025FF2B9C900>
# epoch: 700, cost: 0.00012923004396725446, mocdel: <generator object Module.parameters at 0x0000025FF2B9C900>
# epoch: 800, cost: 6.564263458130881e-05, mocdel: <generator object Module.parameters at 0x0000025FF2B9C900>
# epoch: 900, cost: 3.334394205012359e-05, mocdel: <generator object Module.parameters at 0x0000025F868718C0>
# epoch: 1000, cost: 1.6938598491833545e-05, mocdel: <generator object Module.parameters at 0x0000025F868718C0>
# epoch: 1100, cost: 8.604247341281734e-06, mocdel: <generator object Module.parameters at 0x0000025F868718C0>
# epoch: 1200, cost: 4.370858732727356e-06, mocdel: <generator object Module.parameters at 0x0000025F868718C0>
# epoch: 1300, cost: 2.2206054381967988e-06, mocdel: <generator object Module.parameters at 0x0000025F868718C0>
# epoch: 1400, cost: 1.1282601235507173e-06, mocdel: <generator object Module.parameters at 0x0000025F868718C0>
# epoch: 1500, cost: 5.733102170779603e-07, mocdel: <generator object Module.parameters at 0x0000025F868718C0>
# epoch: 1600, cost: 2.9144308655304485e-07, mocdel: <generator object Module.parameters at 0x0000025F868718C0>
# epoch: 1700, cost: 1.4808182413617033e-07, mocdel: <generator object Module.parameters at 0x0000025FF2B9C900>
# epoch: 1800, cost: 7.529983037102284e-08, mocdel: <generator object Module.parameters at 0x0000025FF2B9C900>
# epoch: 1900, cost: 3.826647443361253e-08, mocdel: <generator object Module.parameters at 0x0000025FF2B9C900>
# epoch: 2000, cost: 1.945769056987956e-08, mocdel: <generator object Module.parameters at 0x0000025FF2B9C900>

# %%
predict = model(torch.FloatTensor([[7],[8]]))
print(predict)
# Out:
# tensor([[7.0003],
#         [8.0004]], grad_fn=<AddmmBackward0>)

# %%
import pandas as pd
import torch

df = pd.read_csv('../data/data-01-test-score.csv')
x_data = df.values[:,:-1]           # 모든 행의 마지막 열앞까지
t_data = df.values[:,-1]            # 모든 행의 마지막 열만
print(x_data.shape)
print(t_data.shape)

t_data = t_data.reshape(-1, 1)
print(t_data.shape)

# 타입 확인
print(type(x_data), type(t_data))

# 텐서플로우로 바꿔주기
x_data1 = torch.from_numpy(x_data).float()
t_data1 = torch.from_numpy(t_data).float()
print(type(x_data1), type(t_data1))     # 훈련데이터 생성완료

indim = x_data1.size(1)
print(indim)
# Out:
# (24, 3)
# (24,)
# (24, 1)
# <class 'numpy.ndarray'> <class 'numpy.ndarray'>
# <class 'torch.Tensor'> <class 'torch.Tensor'>
# 3

# %% [markdown]
# # 클래스 생성

# %%
class MultiLinearRegressionModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear = nn.Linear(indim,1)
    
    # init, forward는 마음대로 짓는게 아니라 정해져있는 이름이다
    def forward(self,x):
        return self.linear(x)

# %% [markdown]
# # 모델 생성

# %%
model = MultiLinearRegressionModel()
optimizer = optim.SGD(model.parameters(), lr=1e-6)      # 1e-6 : 10의 마이너스 6승이라는 뜻

# %%
epochs = 200001
for epoch in range(epochs):
    y = model(x_data1)
    cost = F.mse_loss(y, t_data1)

    optimizer.zero_grad()
    cost.backward()
    optimizer.step()

    if epoch%100==0:
        print(epoch, cost.item(), list(model.parameters()))
# Out:
# 0 6.383651256561279 [Parameter containing:
# tensor([[0.3693, 0.5365, 1.1045]], requires_grad=True), Parameter containing:
# tensor([0.3445], requires_grad=True)]
# 100 6.383577823638916 [Parameter containing:
# tensor([[0.3692, 0.5365, 1.1045]], requires_grad=True), Parameter containing:
# tensor([0.3445], requires_grad=True)]
# 200 6.38351583480835 [Parameter containing:
# tensor([[0.3692, 0.5365, 1.1046]], requires_grad=True), Parameter containing:
# tensor([0.3444], requires_grad=True)]
# 300 6.383452892303467 [Parameter containing:
# tensor([[0.3691, 0.5365, 1.1046]], requires_grad=True), Parameter containing:
# tensor([0.3444], requires_grad=True)]
# 400 6.383373260498047 [Parameter containing:
# tensor([[0.3691, 0.5365, 1.1047]], requires_grad=True), Parameter containing:
# tensor([0.3444], requires_grad=True)]
# 500 6.3833088874816895 [Parameter containing:
# tensor([[0.3690, 0.5365, 1.1048]], requires_grad=True), Parameter containing:
# tensor([0.3444], requires_grad=True)]
# 600 6.38323450088501 [Parameter containing:
# tensor([[0.3690, 0.5365, 1.1048]], requires_grad=True), Parameter containing:
# tensor([0.3444], requires_grad=True)]
# 700 6.383177280426025 [Parameter containing:
# tensor([[0.3689, 0.5365, 1.1049]], requires_grad=True), Parameter containing:
# tensor([0.3443], requires_grad=True)]
# 800 6.383115291595459 [Parameter containing:
# tensor([[0.3689, 0.5364, 1.1049]], requires_grad=True), Parameter containing:
# tensor([0.3443], requires_grad=True)]
# 900 6.3830413818359375 [Parameter containing:
# tensor([[0.3688, 0.5364, 1.1050]], requires_grad=True), Parameter containing:
# tensor([0.3443], requires_grad=True)]
# 1000 6.382980823516846 [Parameter containing:
# tensor([[0.3687, 0.5364, 1.1051]], requires_grad=True), Parameter containing:
# tensor([0.3443], requires_grad=True)]
# 1100 6.382917404174805 [Parameter containing:
# tensor([[0.3687, 0.5364, 1.1051]], requires_grad=True), Parameter containing:
# tensor([0.3443], requires_grad=True)]
# 1200 6.382838726043701 [Parameter containing:
# tensor([[0.3686, 0.5364, 1.1052]], requires_grad=True), Parameter containing:
# tensor([0.3443], requires_grad=True)]
# 1300 6.382775783538818 [Parameter containing:
# tensor([[0.3686, 0.5364, 1.1052]], requires_grad=True), Parameter containing:
# tensor([0.3442], requires_grad=True)]
# 1400 6.382715225219727 [Parameter containing:
# tensor([[0.3685, 0.5364, 1.1053]], requires_grad=True), Parameter containing:
# tensor([0.3442], requires_grad=True)]
# 1500 6.382652282714844 [Parameter containing:
# tensor([[0.3685, 0.5364, 1.1054]], requires_grad=True), Parameter containing:
# tensor([0.3442], requires_grad=True)]
# 1600 6.382587432861328 [Parameter containing:
# tensor([[0.3684, 0.5364, 1.1054]], requires_grad=True), Parameter containing:
# tensor([0.3442], requires_grad=True)]
# 1700 6.382524013519287 [Parameter containing:
# tensor([[0.3684, 0.5364, 1.1055]], requires_grad=True), Parameter containing:
# tensor([0.3442], requires_grad=True)]
# 1800 6.3824639320373535 [Parameter containing:
# tensor([[0.3683, 0.5364, 1.1055]], requires_grad=True), Parameter containing:
# tensor([0.3442], requires_grad=True)]
# 1900 6.382389068603516 [Parameter containing:
# tensor([[0.3683, 0.5364, 1.1056]], requires_grad=True), Parameter containing:
# tensor([0.3441], requires_grad=True)]
# 2000 6.382334232330322 [Parameter containing:
# tensor([[0.3682, 0.5364, 1.1056]], requires_grad=True), Parameter containing:
# tensor([0.3441], requires_grad=True)]
# 2100 6.382270812988281 [Parameter containing:
# tensor([[0.3682, 0.5364, 1.1057]], requires_grad=True), Parameter containing:
# tensor([0.3441], requires_grad=True)]
# 2200 6.382209777832031 [Parameter containing:
# tensor([[0.3681, 0.5364, 1.1058]], requires_grad=True), Parameter containing:
# tensor([0.3441], requires_grad=True)]
# 2300 6.382150650024414 [Parameter containing:
# tensor([[0.3681, 0.5364, 1.1058]], requires_grad=True), Parameter containing:
# tensor([0.3441], requires_grad=True)]
# 2400 6.3820929527282715 [Parameter containing:
# tensor([[0.3680, 0.5364, 1.1059]], requires_grad=True), Parameter containing:
# tensor([0.3440], requires_grad=True)]
# 2500 6.382020950317383 [Parameter containing:
# tensor([[0.3679, 0.5363, 1.1059]], requires_grad=True), Parameter containing:
# tensor([0.3440], requires_grad=True)]
# 2600 6.3819708824157715 [Parameter containing:
# tensor([[0.3679, 0.5363, 1.1060]], requires_grad=True), Parameter containing:
# tensor([0.3440], requires_grad=True)]
# 2700 6.381917953491211 [Parameter containing:
# tensor([[0.3678, 0.5363, 1.1060]], requires_grad=True), Parameter containing:
# tensor([0.3440], requires_grad=True)]
# 2800 6.381849765777588 [Parameter containing:
# tensor([[0.3678, 0.5363, 1.1061]], requires_grad=True), Parameter containing:
# tensor([0.3440], requires_grad=True)]
# 2900 6.381799221038818 [Parameter containing:
# tensor([[0.3677, 0.5363, 1.1061]], requires_grad=True), Parameter containing:
# tensor([0.3440], requires_grad=True)]
# 3000 6.3817362785339355 [Parameter containing:
# tensor([[0.3677, 0.5363, 1.1062]], requires_grad=True), Parameter containing:
# tensor([0.3439], requires_grad=True)]
# 3100 6.381690502166748 [Parameter containing:
# tensor([[0.3676, 0.5363, 1.1062]], requires_grad=True), Parameter containing:
# tensor([0.3439], requires_grad=True)]
# 3200 6.381642818450928 [Parameter containing:
# tensor([[0.3676, 0.5363, 1.1063]], requires_grad=True), Parameter containing:
# tensor([0.3439], requires_grad=True)]
# 3300 6.381590366363525 [Parameter containing:
# tensor([[0.3675, 0.5363, 1.1063]], requires_grad=True), Parameter containing:
# tensor([0.3439], requires_grad=True)]
# 3400 6.381536483764648 [Parameter containing:
# tensor([[0.3675, 0.5363, 1.1064]], requires_grad=True), Parameter containing:
# tensor([0.3439], requires_grad=True)]
# 3500 6.381471633911133 [Parameter containing:
# tensor([[0.3675, 0.5363, 1.1064]], requires_grad=True), Parameter containing:
# tensor([0.3438], requires_grad=True)]
# 3600 6.381425380706787 [Parameter containing:
# tensor([[0.3674, 0.5363, 1.1065]], requires_grad=True), Parameter containing:
# tensor([0.3438], requires_grad=True)]
# 3700 6.381381511688232 [Parameter containing:
# tensor([[0.3674, 0.5363, 1.1065]], requires_grad=True), Parameter containing:
# tensor([0.3438], requires_grad=True)]
# 3800 6.3813252449035645 [Parameter containing:
# tensor([[0.3673, 0.5363, 1.1066]], requires_grad=True), Parameter containing:
# tensor([0.3438], requires_grad=True)]
# 3900 6.381269931793213 [Parameter containing:
# tensor([[0.3673, 0.5363, 1.1066]], requires_grad=True), Parameter containing:
# tensor([0.3438], requires_grad=True)]
# 4000 6.381226062774658 [Parameter containing:
# tensor([[0.3672, 0.5363, 1.1067]], requires_grad=True), Parameter containing:
# tensor([0.3438], requires_grad=True)]
# 4100 6.381173610687256 [Parameter containing:
# tensor([[0.3672, 0.5363, 1.1067]], requires_grad=True), Parameter containing:
# tensor([0.3437], requires_grad=True)]
# 4200 6.381120681762695 [Parameter containing:
# tensor([[0.3671, 0.5363, 1.1068]], requires_grad=True), Parameter containing:
# tensor([0.3437], requires_grad=True)]
# 4300 6.381076812744141 [Parameter containing:
# tensor([[0.3671, 0.5363, 1.1068]], requires_grad=True), Parameter containing:
# tensor([0.3437], requires_grad=True)]
# 4400 6.3810248374938965 [Parameter containing:
# tensor([[0.3670, 0.5363, 1.1069]], requires_grad=True), Parameter containing:
# tensor([0.3437], requires_grad=True)]
# 4500 6.380972385406494 [Parameter containing:
# tensor([[0.3670, 0.5363, 1.1069]], requires_grad=True), Parameter containing:
# tensor([0.3437], requires_grad=True)]
# 4600 6.380922794342041 [Parameter containing:
# tensor([[0.3669, 0.5363, 1.1070]], requires_grad=True), Parameter containing:
# tensor([0.3437], requires_grad=True)]
# 4700 6.380874156951904 [Parameter containing:
# tensor([[0.3669, 0.5363, 1.1070]], requires_grad=True), Parameter containing:
# tensor([0.3436], requires_grad=True)]
# 4800 6.380825042724609 [Parameter containing:
# tensor([[0.3668, 0.5363, 1.1071]], requires_grad=True), Parameter containing:
# tensor([0.3436], requires_grad=True)]
# 4900 6.38076639175415 [Parameter containing:
# tensor([[0.3668, 0.5363, 1.1071]], requires_grad=True), Parameter containing:
# tensor([0.3436], requires_grad=True)]
# 5000 6.380722522735596 [Parameter containing:
# tensor([[0.3667, 0.5363, 1.1072]], requires_grad=True), Parameter containing:
# tensor([0.3436], requires_grad=True)]
# 5100 6.38067102432251 [Parameter containing:
# tensor([[0.3667, 0.5363, 1.1072]], requires_grad=True), Parameter containing:
# tensor([0.3436], requires_grad=True)]
# 5200 6.3806233406066895 [Parameter containing:
# tensor([[0.3666, 0.5363, 1.1072]], requires_grad=True), Parameter containing:
# tensor([0.3435], requires_grad=True)]
# 5300 6.380579471588135 [Parameter containing:
# tensor([[0.3666, 0.5363, 1.1073]], requires_grad=True), Parameter containing:
# tensor([0.3435], requires_grad=True)]
# 5400 6.3805251121521 [Parameter containing:
# tensor([[0.3665, 0.5363, 1.1073]], requires_grad=True), Parameter containing:
# tensor([0.3435], requires_grad=True)]
# 5500 6.380472660064697 [Parameter containing:
# tensor([[0.3665, 0.5363, 1.1074]], requires_grad=True), Parameter containing:
# tensor([0.3435], requires_grad=True)]
# 5600 6.380438327789307 [Parameter containing:
# tensor([[0.3664, 0.5363, 1.1074]], requires_grad=True), Parameter containing:
# tensor([0.3435], requires_grad=True)]
# 5700 6.380380630493164 [Parameter containing:
# tensor([[0.3664, 0.5363, 1.1075]], requires_grad=True), Parameter containing:
# tensor([0.3435], requires_grad=True)]
# 5800 6.380330562591553 [Parameter containing:
# tensor([[0.3664, 0.5363, 1.1075]], requires_grad=True), Parameter containing:
# tensor([0.3434], requires_grad=True)]
# 5900 6.380285739898682 [Parameter containing:
# tensor([[0.3663, 0.5363, 1.1076]], requires_grad=True), Parameter containing:
# tensor([0.3434], requires_grad=True)]
# 6000 6.380245685577393 [Parameter containing:
# tensor([[0.3663, 0.5363, 1.1076]], requires_grad=True), Parameter containing:
# tensor([0.3434], requires_grad=True)]
# 6100 6.380185604095459 [Parameter containing:
# tensor([[0.3662, 0.5363, 1.1077]], requires_grad=True), Parameter containing:
# tensor([0.3434], requires_grad=True)]
# 6200 6.380138874053955 [Parameter containing:
# tensor([[0.3662, 0.5363, 1.1077]], requires_grad=True), Parameter containing:
# tensor([0.3434], requires_grad=True)]
# 6300 6.380092144012451 [Parameter containing:
# tensor([[0.3661, 0.5363, 1.1078]], requires_grad=True), Parameter containing:
# tensor([0.3433], requires_grad=True)]
# 6400 6.38005256652832 [Parameter containing:
# tensor([[0.3661, 0.5363, 1.1078]], requires_grad=True), Parameter containing:
# tensor([0.3433], requires_grad=True)]
# 6500 6.379997730255127 [Parameter containing:
# tensor([[0.3660, 0.5363, 1.1079]], requires_grad=True), Parameter containing:
# tensor([0.3433], requires_grad=True)]
# 6600 6.3799567222595215 [Parameter containing:
# tensor([[0.3660, 0.5363, 1.1079]], requires_grad=True), Parameter containing:
# tensor([0.3433], requires_grad=True)]
# 6700 6.3799147605896 [Parameter containing:
# tensor([[0.3659, 0.5363, 1.1080]], requires_grad=True), Parameter containing:
# tensor([0.3433], requires_grad=True)]
# 6800 6.379863739013672 [Parameter containing:
# tensor([[0.3659, 0.5363, 1.1080]], requires_grad=True), Parameter containing:
# tensor([0.3433], requires_grad=True)]
# 6900 6.379823684692383 [Parameter containing:
# tensor([[0.3658, 0.5363, 1.1081]], requires_grad=True), Parameter containing:
# tensor([0.3432], requires_grad=True)]
# 7000 6.379767894744873 [Parameter containing:
# tensor([[0.3658, 0.5363, 1.1081]], requires_grad=True), Parameter containing:
# tensor([0.3432], requires_grad=True)]
# 7100 6.379709720611572 [Parameter containing:
# tensor([[0.3657, 0.5363, 1.1082]], requires_grad=True), Parameter containing:
# tensor([0.3432], requires_grad=True)]
# 7200 6.379675388336182 [Parameter containing:
# tensor([[0.3657, 0.5363, 1.1082]], requires_grad=True), Parameter containing:
# tensor([0.3432], requires_grad=True)]
# 7300 6.379623889923096 [Parameter containing:
# tensor([[0.3656, 0.5363, 1.1082]], requires_grad=True), Parameter containing:
# tensor([0.3432], requires_grad=True)]
# 7400 6.379578113555908 [Parameter containing:
# tensor([[0.3656, 0.5363, 1.1083]], requires_grad=True), Parameter containing:
# tensor([0.3432], requires_grad=True)]
# 7500 6.379538059234619 [Parameter containing:
# tensor([[0.3655, 0.5363, 1.1083]], requires_grad=True), Parameter containing:
# tensor([0.3431], requires_grad=True)]
# 7600 6.379490375518799 [Parameter containing:
# tensor([[0.3655, 0.5363, 1.1084]], requires_grad=True), Parameter containing:
# tensor([0.3431], requires_grad=True)]
# 7700 6.3794426918029785 [Parameter containing:
# tensor([[0.3655, 0.5363, 1.1084]], requires_grad=True), Parameter containing:
# tensor([0.3431], requires_grad=True)]
# 7800 6.379396915435791 [Parameter containing:
# tensor([[0.3654, 0.5363, 1.1085]], requires_grad=True), Parameter containing:
# tensor([0.3431], requires_grad=True)]
# 7900 6.379362106323242 [Parameter containing:
# tensor([[0.3654, 0.5363, 1.1085]], requires_grad=True), Parameter containing:
# tensor([0.3431], requires_grad=True)]
# 8000 6.379310131072998 [Parameter containing:
# tensor([[0.3653, 0.5363, 1.1086]], requires_grad=True), Parameter containing:
# tensor([0.3430], requires_grad=True)]
# 8100 6.379270076751709 [Parameter containing:
# tensor([[0.3653, 0.5363, 1.1086]], requires_grad=True), Parameter containing:
# tensor([0.3430], requires_grad=True)]
# 8200 6.37923002243042 [Parameter containing:
# tensor([[0.3652, 0.5363, 1.1087]], requires_grad=True), Parameter containing:
# tensor([0.3430], requires_grad=True)]
# 8300 6.379188060760498 [Parameter containing:
# tensor([[0.3652, 0.5363, 1.1087]], requires_grad=True), Parameter containing:
# tensor([0.3430], requires_grad=True)]
# 8400 6.379138469696045 [Parameter containing:
# tensor([[0.3651, 0.5363, 1.1088]], requires_grad=True), Parameter containing:
# tensor([0.3430], requires_grad=True)]
# 8500 6.379104137420654 [Parameter containing:
# tensor([[0.3651, 0.5363, 1.1088]], requires_grad=True), Parameter containing:
# tensor([0.3430], requires_grad=True)]
# 8600 6.37905740737915 [Parameter containing:
# tensor([[0.3650, 0.5363, 1.1088]], requires_grad=True), Parameter containing:
# tensor([0.3429], requires_grad=True)]
# 8700 6.379016876220703 [Parameter containing:
# tensor([[0.3650, 0.5363, 1.1089]], requires_grad=True), Parameter containing:
# tensor([0.3429], requires_grad=True)]
# 8800 6.378987789154053 [Parameter containing:
# tensor([[0.3650, 0.5363, 1.1089]], requires_grad=True), Parameter containing:
# tensor([0.3429], requires_grad=True)]
# 8900 6.37894868850708 [Parameter containing:
# tensor([[0.3649, 0.5363, 1.1090]], requires_grad=True), Parameter containing:
# tensor([0.3429], requires_grad=True)]
# 9000 6.378906726837158 [Parameter containing:
# tensor([[0.3649, 0.5363, 1.1090]], requires_grad=True), Parameter containing:
# tensor([0.3429], requires_grad=True)]
# 9100 6.378868103027344 [Parameter containing:
# tensor([[0.3648, 0.5363, 1.1091]], requires_grad=True), Parameter containing:
# tensor([0.3428], requires_grad=True)]
# 9200 6.378829479217529 [Parameter containing:
# tensor([[0.3648, 0.5363, 1.1091]], requires_grad=True), Parameter containing:
# tensor([0.3428], requires_grad=True)]
# 9300 6.378784656524658 [Parameter containing:
# tensor([[0.3647, 0.5363, 1.1091]], requires_grad=True), Parameter containing:
# tensor([0.3428], requires_grad=True)]
# 9400 6.378757953643799 [Parameter containing:
# tensor([[0.3647, 0.5363, 1.1092]], requires_grad=True), Parameter containing:
# tensor([0.3428], requires_grad=True)]
# 9500 6.378712177276611 [Parameter containing:
# tensor([[0.3647, 0.5363, 1.1092]], requires_grad=True), Parameter containing:
# tensor([0.3428], requires_grad=True)]
# 9600 6.378674030303955 [Parameter containing:
# tensor([[0.3646, 0.5363, 1.1093]], requires_grad=True), Parameter containing:
# tensor([0.3428], requires_grad=True)]
# 9700 6.378641128540039 [Parameter containing:
# tensor([[0.3646, 0.5363, 1.1093]], requires_grad=True), Parameter containing:
# tensor([0.3427], requires_grad=True)]
# 9800 6.378593921661377 [Parameter containing:
# tensor([[0.3645, 0.5363, 1.1093]], requires_grad=True), Parameter containing:
# tensor([0.3427], requires_grad=True)]
# 9900 6.378559589385986 [Parameter containing:
# tensor([[0.3645, 0.5363, 1.1094]], requires_grad=True), Parameter containing:
# tensor([0.3427], requires_grad=True)]
# 10000 6.378528594970703 [Parameter containing:
# tensor([[0.3645, 0.5363, 1.1094]], requires_grad=True), Parameter containing:
# tensor([0.3427], requires_grad=True)]
# 10100 6.378488540649414 [Parameter containing:
# tensor([[0.3644, 0.5363, 1.1095]], requires_grad=True), Parameter containing:
# tensor([0.3427], requires_grad=True)]
# 10200 6.378452777862549 [Parameter containing:
# tensor([[0.3644, 0.5363, 1.1095]], requires_grad=True), Parameter containing:
# tensor([0.3427], requires_grad=True)]
# 10300 6.378416538238525 [Parameter containing:
# tensor([[0.3643, 0.5363, 1.1095]], requires_grad=True), Parameter containing:
# tensor([0.3426], requires_grad=True)]
# 10400 6.378380298614502 [Parameter containing:
# tensor([[0.3643, 0.5363, 1.1096]], requires_grad=True), Parameter containing:
# tensor([0.3426], requires_grad=True)]
# 10500 6.378345012664795 [Parameter containing:
# tensor([[0.3643, 0.5363, 1.1096]], requires_grad=True), Parameter containing:
# tensor([0.3426], requires_grad=True)]
# 10600 6.378315448760986 [Parameter containing:
# tensor([[0.3642, 0.5363, 1.1097]], requires_grad=True), Parameter containing:
# tensor([0.3426], requires_grad=True)]
# 10700 6.3782830238342285 [Parameter containing:
# tensor([[0.3642, 0.5363, 1.1097]], requires_grad=True), Parameter containing:
# tensor([0.3426], requires_grad=True)]
# 10800 6.378252029418945 [Parameter containing:
# tensor([[0.3641, 0.5363, 1.1097]], requires_grad=True), Parameter containing:
# tensor([0.3425], requires_grad=True)]
# 10900 6.378217697143555 [Parameter containing:
# tensor([[0.3641, 0.5363, 1.1098]], requires_grad=True), Parameter containing:
# tensor([0.3425], requires_grad=True)]
# 11000 6.3781890869140625 [Parameter containing:
# tensor([[0.3641, 0.5363, 1.1098]], requires_grad=True), Parameter containing:
# tensor([0.3425], requires_grad=True)]
# 11100 6.378153324127197 [Parameter containing:
# tensor([[0.3640, 0.5363, 1.1098]], requires_grad=True), Parameter containing:
# tensor([0.3425], requires_grad=True)]
# 11200 6.37810754776001 [Parameter containing:
# tensor([[0.3640, 0.5363, 1.1099]], requires_grad=True), Parameter containing:
# tensor([0.3425], requires_grad=True)]
# 11300 6.378082752227783 [Parameter containing:
# tensor([[0.3639, 0.5363, 1.1099]], requires_grad=True), Parameter containing:
# tensor([0.3425], requires_grad=True)]
# 11400 6.378045558929443 [Parameter containing:
# tensor([[0.3639, 0.5363, 1.1099]], requires_grad=True), Parameter containing:
# tensor([0.3424], requires_grad=True)]
# 11500 6.3780198097229 [Parameter containing:
# tensor([[0.3639, 0.5363, 1.1100]], requires_grad=True), Parameter containing:
# tensor([0.3424], requires_grad=True)]
# 11600 6.377987384796143 [Parameter containing:
# tensor([[0.3638, 0.5363, 1.1100]], requires_grad=True), Parameter containing:
# tensor([0.3424], requires_grad=True)]
# 11700 6.377950191497803 [Parameter containing:
# tensor([[0.3638, 0.5363, 1.1101]], requires_grad=True), Parameter containing:
# tensor([0.3424], requires_grad=True)]
# 11800 6.377915859222412 [Parameter containing:
# tensor([[0.3638, 0.5363, 1.1101]], requires_grad=True), Parameter containing:
# tensor([0.3424], requires_grad=True)]
# 11900 6.37788200378418 [Parameter containing:
# tensor([[0.3637, 0.5363, 1.1101]], requires_grad=True), Parameter containing:
# tensor([0.3423], requires_grad=True)]
# 12000 6.377859115600586 [Parameter containing:
# tensor([[0.3637, 0.5363, 1.1102]], requires_grad=True), Parameter containing:
# tensor([0.3423], requires_grad=True)]
# 12100 6.377821445465088 [Parameter containing:
# tensor([[0.3636, 0.5363, 1.1102]], requires_grad=True), Parameter containing:
# tensor([0.3423], requires_grad=True)]
# 12200 6.377788543701172 [Parameter containing:
# tensor([[0.3636, 0.5363, 1.1102]], requires_grad=True), Parameter containing:
# tensor([0.3423], requires_grad=True)]
# 12300 6.3777689933776855 [Parameter containing:
# tensor([[0.3636, 0.5363, 1.1103]], requires_grad=True), Parameter containing:
# tensor([0.3423], requires_grad=True)]
# 12400 6.3777337074279785 [Parameter containing:
# tensor([[0.3635, 0.5363, 1.1103]], requires_grad=True), Parameter containing:
# tensor([0.3423], requires_grad=True)]
# 12500 6.37770414352417 [Parameter containing:
# tensor([[0.3635, 0.5363, 1.1103]], requires_grad=True), Parameter containing:
# tensor([0.3422], requires_grad=True)]
# 12600 6.377659320831299 [Parameter containing:
# tensor([[0.3635, 0.5363, 1.1104]], requires_grad=True), Parameter containing:
# tensor([0.3422], requires_grad=True)]
# 12700 6.37764310836792 [Parameter containing:
# tensor([[0.3634, 0.5363, 1.1104]], requires_grad=True), Parameter containing:
# tensor([0.3422], requires_grad=True)]
# 12800 6.3776164054870605 [Parameter containing:
# tensor([[0.3634, 0.5363, 1.1105]], requires_grad=True), Parameter containing:
# tensor([0.3422], requires_grad=True)]
# 12900 6.377578258514404 [Parameter containing:
# tensor([[0.3633, 0.5363, 1.1105]], requires_grad=True), Parameter containing:
# tensor([0.3422], requires_grad=True)]
# 13000 6.37755012512207 [Parameter containing:
# tensor([[0.3633, 0.5363, 1.1105]], requires_grad=True), Parameter containing:
# tensor([0.3421], requires_grad=True)]
# 13100 6.377508163452148 [Parameter containing:
# tensor([[0.3633, 0.5363, 1.1106]], requires_grad=True), Parameter containing:
# tensor([0.3421], requires_grad=True)]
# 13200 6.3774895668029785 [Parameter containing:
# tensor([[0.3632, 0.5363, 1.1106]], requires_grad=True), Parameter containing:
# tensor([0.3421], requires_grad=True)]
# 13300 6.3774590492248535 [Parameter containing:
# tensor([[0.3632, 0.5363, 1.1106]], requires_grad=True), Parameter containing:
# tensor([0.3421], requires_grad=True)]
# 13400 6.3774285316467285 [Parameter containing:
# tensor([[0.3632, 0.5363, 1.1107]], requires_grad=True), Parameter containing:
# tensor([0.3421], requires_grad=True)]
# 13500 6.37739372253418 [Parameter containing:
# tensor([[0.3631, 0.5363, 1.1107]], requires_grad=True), Parameter containing:
# tensor([0.3421], requires_grad=True)]
# 13600 6.377361297607422 [Parameter containing:
# tensor([[0.3631, 0.5363, 1.1107]], requires_grad=True), Parameter containing:
# tensor([0.3420], requires_grad=True)]
# 13700 6.377343654632568 [Parameter containing:
# tensor([[0.3631, 0.5363, 1.1108]], requires_grad=True), Parameter containing:
# tensor([0.3420], requires_grad=True)]
# 13800 6.377313137054443 [Parameter containing:
# tensor([[0.3630, 0.5363, 1.1108]], requires_grad=True), Parameter containing:
# tensor([0.3420], requires_grad=True)]
# 13900 6.3772735595703125 [Parameter containing:
# tensor([[0.3630, 0.5363, 1.1108]], requires_grad=True), Parameter containing:
# tensor([0.3420], requires_grad=True)]
# 14000 6.377251148223877 [Parameter containing:
# tensor([[0.3629, 0.5363, 1.1109]], requires_grad=True), Parameter containing:
# tensor([0.3420], requires_grad=True)]
# 14100 6.377228260040283 [Parameter containing:
# tensor([[0.3629, 0.5363, 1.1109]], requires_grad=True), Parameter containing:
# tensor([0.3420], requires_grad=True)]
# 14200 6.377185344696045 [Parameter containing:
# tensor([[0.3629, 0.5363, 1.1110]], requires_grad=True), Parameter containing:
# tensor([0.3419], requires_grad=True)]
# 14300 6.377150058746338 [Parameter containing:
# tensor([[0.3628, 0.5363, 1.1110]], requires_grad=True), Parameter containing:
# tensor([0.3419], requires_grad=True)]
# 14400 6.377126693725586 [Parameter containing:
# tensor([[0.3628, 0.5363, 1.1110]], requires_grad=True), Parameter containing:
# tensor([0.3419], requires_grad=True)]
# 14500 6.377102375030518 [Parameter containing:
# tensor([[0.3628, 0.5363, 1.1111]], requires_grad=True), Parameter containing:
# tensor([0.3419], requires_grad=True)]
# 14600 6.3770623207092285 [Parameter containing:
# tensor([[0.3627, 0.5363, 1.1111]], requires_grad=True), Parameter containing:
# tensor([0.3419], requires_grad=True)]
# 14700 6.377040863037109 [Parameter containing:
# tensor([[0.3627, 0.5363, 1.1111]], requires_grad=True), Parameter containing:
# tensor([0.3418], requires_grad=True)]
# 14800 6.377010345458984 [Parameter containing:
# tensor([[0.3627, 0.5363, 1.1112]], requires_grad=True), Parameter containing:
# tensor([0.3418], requires_grad=True)]
# 14900 6.376986980438232 [Parameter containing:
# tensor([[0.3626, 0.5363, 1.1112]], requires_grad=True), Parameter containing:
# tensor([0.3418], requires_grad=True)]
# 15000 6.376955509185791 [Parameter containing:
# tensor([[0.3626, 0.5363, 1.1112]], requires_grad=True), Parameter containing:
# tensor([0.3418], requires_grad=True)]
# 15100 6.376926422119141 [Parameter containing:
# tensor([[0.3625, 0.5363, 1.1113]], requires_grad=True), Parameter containing:
# tensor([0.3418], requires_grad=True)]
# 15200 6.376897811889648 [Parameter containing:
# tensor([[0.3625, 0.5363, 1.1113]], requires_grad=True), Parameter containing:
# tensor([0.3418], requires_grad=True)]
# 15300 6.376869201660156 [Parameter containing:
# tensor([[0.3625, 0.5363, 1.1113]], requires_grad=True), Parameter containing:
# tensor([0.3417], requires_grad=True)]
# 15400 6.376848220825195 [Parameter containing:
# tensor([[0.3624, 0.5363, 1.1114]], requires_grad=True), Parameter containing:
# tensor([0.3417], requires_grad=True)]
# 15500 6.3768134117126465 [Parameter containing:
# tensor([[0.3624, 0.5363, 1.1114]], requires_grad=True), Parameter containing:
# tensor([0.3417], requires_grad=True)]
# 15600 6.3767852783203125 [Parameter containing:
# tensor([[0.3624, 0.5363, 1.1115]], requires_grad=True), Parameter containing:
# tensor([0.3417], requires_grad=True)]
# 15700 6.376755237579346 [Parameter containing:
# tensor([[0.3623, 0.5363, 1.1115]], requires_grad=True), Parameter containing:
# tensor([0.3417], requires_grad=True)]
# 15800 6.376720428466797 [Parameter containing:
# tensor([[0.3623, 0.5363, 1.1115]], requires_grad=True), Parameter containing:
# tensor([0.3416], requires_grad=True)]
# 15900 6.376705646514893 [Parameter containing:
# tensor([[0.3622, 0.5363, 1.1116]], requires_grad=True), Parameter containing:
# tensor([0.3416], requires_grad=True)]
# 16000 6.376678943634033 [Parameter containing:
# tensor([[0.3622, 0.5363, 1.1116]], requires_grad=True), Parameter containing:
# tensor([0.3416], requires_grad=True)]
# 16100 6.376654148101807 [Parameter containing:
# tensor([[0.3622, 0.5363, 1.1116]], requires_grad=True), Parameter containing:
# tensor([0.3416], requires_grad=True)]
# 16200 6.376617908477783 [Parameter containing:
# tensor([[0.3621, 0.5363, 1.1117]], requires_grad=True), Parameter containing:
# tensor([0.3416], requires_grad=True)]
# 16300 6.376589298248291 [Parameter containing:
# tensor([[0.3621, 0.5363, 1.1117]], requires_grad=True), Parameter containing:
# tensor([0.3416], requires_grad=True)]
# 16400 6.376550197601318 [Parameter containing:
# tensor([[0.3621, 0.5363, 1.1117]], requires_grad=True), Parameter containing:
# tensor([0.3415], requires_grad=True)]
# 16500 6.3765387535095215 [Parameter containing:
# tensor([[0.3620, 0.5363, 1.1118]], requires_grad=True), Parameter containing:
# tensor([0.3415], requires_grad=True)]
# 16600 6.3765106201171875 [Parameter containing:
# tensor([[0.3620, 0.5363, 1.1118]], requires_grad=True), Parameter containing:
# tensor([0.3415], requires_grad=True)]
# 16700 6.376484394073486 [Parameter containing:
# tensor([[0.3620, 0.5363, 1.1118]], requires_grad=True), Parameter containing:
# tensor([0.3415], requires_grad=True)]
# 16800 6.376453876495361 [Parameter containing:
# tensor([[0.3619, 0.5363, 1.1119]], requires_grad=True), Parameter containing:
# tensor([0.3415], requires_grad=True)]
# 16900 6.376437664031982 [Parameter containing:
# tensor([[0.3619, 0.5363, 1.1119]], requires_grad=True), Parameter containing:
# tensor([0.3415], requires_grad=True)]
# 17000 6.376408100128174 [Parameter containing:
# tensor([[0.3619, 0.5363, 1.1119]], requires_grad=True), Parameter containing:
# tensor([0.3414], requires_grad=True)]
# 17100 6.376379489898682 [Parameter containing:
# tensor([[0.3618, 0.5363, 1.1120]], requires_grad=True), Parameter containing:
# tensor([0.3414], requires_grad=True)]
# 17200 6.376354694366455 [Parameter containing:
# tensor([[0.3618, 0.5363, 1.1120]], requires_grad=True), Parameter containing:
# tensor([0.3414], requires_grad=True)]
# 17300 6.376332759857178 [Parameter containing:
# tensor([[0.3617, 0.5363, 1.1121]], requires_grad=True), Parameter containing:
# tensor([0.3414], requires_grad=True)]
# 17400 6.3762993812561035 [Parameter containing:
# tensor([[0.3617, 0.5363, 1.1121]], requires_grad=True), Parameter containing:
# tensor([0.3414], requires_grad=True)]
# 17500 6.376270771026611 [Parameter containing:
# tensor([[0.3617, 0.5363, 1.1121]], requires_grad=True), Parameter containing:
# tensor([0.3413], requires_grad=True)]
# 17600 6.376237392425537 [Parameter containing:
# tensor([[0.3616, 0.5363, 1.1122]], requires_grad=True), Parameter containing:
# tensor([0.3413], requires_grad=True)]
# 17700 6.376224040985107 [Parameter containing:
# tensor([[0.3616, 0.5363, 1.1122]], requires_grad=True), Parameter containing:
# tensor([0.3413], requires_grad=True)]
# 17800 6.376189708709717 [Parameter containing:
# tensor([[0.3616, 0.5363, 1.1122]], requires_grad=True), Parameter containing:
# tensor([0.3413], requires_grad=True)]
# 17900 6.376170635223389 [Parameter containing:
# tensor([[0.3615, 0.5363, 1.1123]], requires_grad=True), Parameter containing:
# tensor([0.3413], requires_grad=True)]
# 18000 6.376145839691162 [Parameter containing:
# tensor([[0.3615, 0.5363, 1.1123]], requires_grad=True), Parameter containing:
# tensor([0.3413], requires_grad=True)]
# 18100 6.376125812530518 [Parameter containing:
# tensor([[0.3615, 0.5363, 1.1123]], requires_grad=True), Parameter containing:
# tensor([0.3412], requires_grad=True)]
# 18200 6.376097202301025 [Parameter containing:
# tensor([[0.3614, 0.5363, 1.1124]], requires_grad=True), Parameter containing:
# tensor([0.3412], requires_grad=True)]
# 18300 6.376064300537109 [Parameter containing:
# tensor([[0.3614, 0.5363, 1.1124]], requires_grad=True), Parameter containing:
# tensor([0.3412], requires_grad=True)]
# 18400 6.37605619430542 [Parameter containing:
# tensor([[0.3614, 0.5363, 1.1124]], requires_grad=True), Parameter containing:
# tensor([0.3412], requires_grad=True)]
# 18500 6.3760247230529785 [Parameter containing:
# tensor([[0.3613, 0.5363, 1.1124]], requires_grad=True), Parameter containing:
# tensor([0.3412], requires_grad=True)]
# 18600 6.376010417938232 [Parameter containing:
# tensor([[0.3613, 0.5363, 1.1125]], requires_grad=True), Parameter containing:
# tensor([0.3411], requires_grad=True)]
# 18700 6.375980854034424 [Parameter containing:
# tensor([[0.3613, 0.5363, 1.1125]], requires_grad=True), Parameter containing:
# tensor([0.3411], requires_grad=True)]
# 18800 6.375965118408203 [Parameter containing:
# tensor([[0.3612, 0.5363, 1.1125]], requires_grad=True), Parameter containing:
# tensor([0.3411], requires_grad=True)]
# 18900 6.375946521759033 [Parameter containing:
# tensor([[0.3612, 0.5363, 1.1125]], requires_grad=True), Parameter containing:
# tensor([0.3411], requires_grad=True)]
# 19000 6.375921249389648 [Parameter containing:
# tensor([[0.3612, 0.5363, 1.1126]], requires_grad=True), Parameter containing:
# tensor([0.3411], requires_grad=True)]
# 19100 6.375898361206055 [Parameter containing:
# tensor([[0.3611, 0.5363, 1.1126]], requires_grad=True), Parameter containing:
# tensor([0.3411], requires_grad=True)]
# 19200 6.375885009765625 [Parameter containing:
# tensor([[0.3611, 0.5363, 1.1126]], requires_grad=True), Parameter containing:
# tensor([0.3410], requires_grad=True)]
# 19300 6.37584924697876 [Parameter containing:
# tensor([[0.3611, 0.5364, 1.1126]], requires_grad=True), Parameter containing:
# tensor([0.3410], requires_grad=True)]
# 19400 6.3758392333984375 [Parameter containing:
# tensor([[0.3610, 0.5364, 1.1127]], requires_grad=True), Parameter containing:
# tensor([0.3410], requires_grad=True)]
# 19500 6.3758158683776855 [Parameter containing:
# tensor([[0.3610, 0.5364, 1.1127]], requires_grad=True), Parameter containing:
# tensor([0.3410], requires_grad=True)]
# 19600 6.375795841217041 [Parameter containing:
# tensor([[0.3610, 0.5364, 1.1127]], requires_grad=True), Parameter containing:
# tensor([0.3410], requires_grad=True)]
# 19700 6.375768661499023 [Parameter containing:
# tensor([[0.3609, 0.5364, 1.1127]], requires_grad=True), Parameter containing:
# tensor([0.3410], requires_grad=True)]
# 19800 6.375747203826904 [Parameter containing:
# tensor([[0.3609, 0.5364, 1.1128]], requires_grad=True), Parameter containing:
# tensor([0.3409], requires_grad=True)]
# 19900 6.375735759735107 [Parameter containing:
# tensor([[0.3609, 0.5364, 1.1128]], requires_grad=True), Parameter containing:
# tensor([0.3409], requires_grad=True)]
# 20000 6.3757147789001465 [Parameter containing:
# tensor([[0.3609, 0.5364, 1.1128]], requires_grad=True), Parameter containing:
# tensor([0.3409], requires_grad=True)]
# 20100 6.375692367553711 [Parameter containing:
# tensor([[0.3608, 0.5364, 1.1128]], requires_grad=True), Parameter containing:
# tensor([0.3409], requires_grad=True)]
# 20200 6.375673770904541 [Parameter containing:
# tensor([[0.3608, 0.5364, 1.1129]], requires_grad=True), Parameter containing:
# tensor([0.3409], requires_grad=True)]
# 20300 6.3756422996521 [Parameter containing:
# tensor([[0.3608, 0.5364, 1.1129]], requires_grad=True), Parameter containing:
# tensor([0.3408], requires_grad=True)]
# 20400 6.375637054443359 [Parameter containing:
# tensor([[0.3607, 0.5364, 1.1129]], requires_grad=True), Parameter containing:
# tensor([0.3408], requires_grad=True)]
# 20500 6.3756184577941895 [Parameter containing:
# tensor([[0.3607, 0.5364, 1.1129]], requires_grad=True), Parameter containing:
# tensor([0.3408], requires_grad=True)]
# 20600 6.37559700012207 [Parameter containing:
# tensor([[0.3607, 0.5364, 1.1130]], requires_grad=True), Parameter containing:
# tensor([0.3408], requires_grad=True)]
# 20700 6.3755784034729 [Parameter containing:
# tensor([[0.3606, 0.5364, 1.1130]], requires_grad=True), Parameter containing:
# tensor([0.3408], requires_grad=True)]
# 20800 6.3755574226379395 [Parameter containing:
# tensor([[0.3606, 0.5364, 1.1130]], requires_grad=True), Parameter containing:
# tensor([0.3408], requires_grad=True)]
# 20900 6.3755340576171875 [Parameter containing:
# tensor([[0.3606, 0.5364, 1.1130]], requires_grad=True), Parameter containing:
# tensor([0.3407], requires_grad=True)]
# 21000 6.375514984130859 [Parameter containing:
# tensor([[0.3606, 0.5365, 1.1131]], requires_grad=True), Parameter containing:
# tensor([0.3407], requires_grad=True)]
# 21100 6.375497341156006 [Parameter containing:
# tensor([[0.3605, 0.5365, 1.1131]], requires_grad=True), Parameter containing:
# tensor([0.3407], requires_grad=True)]
# 21200 6.375476837158203 [Parameter containing:
# tensor([[0.3605, 0.5365, 1.1131]], requires_grad=True), Parameter containing:
# tensor([0.3407], requires_grad=True)]
# 21300 6.375460147857666 [Parameter containing:
# tensor([[0.3605, 0.5365, 1.1131]], requires_grad=True), Parameter containing:
# tensor([0.3407], requires_grad=True)]
# 21400 6.3754353523254395 [Parameter containing:
# tensor([[0.3604, 0.5365, 1.1132]], requires_grad=True), Parameter containing:
# tensor([0.3406], requires_grad=True)]
# 21500 6.375421047210693 [Parameter containing:
# tensor([[0.3604, 0.5365, 1.1132]], requires_grad=True), Parameter containing:
# tensor([0.3406], requires_grad=True)]
# 21600 6.375407695770264 [Parameter containing:
# tensor([[0.3604, 0.5365, 1.1132]], requires_grad=True), Parameter containing:
# tensor([0.3406], requires_grad=True)]
# 21700 6.375385284423828 [Parameter containing:
# tensor([[0.3603, 0.5365, 1.1132]], requires_grad=True), Parameter containing:
# tensor([0.3406], requires_grad=True)]
# 21800 6.375363826751709 [Parameter containing:
# tensor([[0.3603, 0.5365, 1.1132]], requires_grad=True), Parameter containing:
# tensor([0.3406], requires_grad=True)]
# 21900 6.375344753265381 [Parameter containing:
# tensor([[0.3603, 0.5365, 1.1133]], requires_grad=True), Parameter containing:
# tensor([0.3406], requires_grad=True)]
# 22000 6.375325679779053 [Parameter containing:
# tensor([[0.3603, 0.5365, 1.1133]], requires_grad=True), Parameter containing:
# tensor([0.3405], requires_grad=True)]
# 22100 6.375307559967041 [Parameter containing:
# tensor([[0.3602, 0.5365, 1.1133]], requires_grad=True), Parameter containing:
# tensor([0.3405], requires_grad=True)]
# 22200 6.375286102294922 [Parameter containing:
# tensor([[0.3602, 0.5365, 1.1133]], requires_grad=True), Parameter containing:
# tensor([0.3405], requires_grad=True)]
# 22300 6.375270366668701 [Parameter containing:
# tensor([[0.3602, 0.5365, 1.1134]], requires_grad=True), Parameter containing:
# tensor([0.3405], requires_grad=True)]
# 22400 6.3752593994140625 [Parameter containing:
# tensor([[0.3601, 0.5365, 1.1134]], requires_grad=True), Parameter containing:
# tensor([0.3405], requires_grad=True)]
# 22500 6.375242233276367 [Parameter containing:
# tensor([[0.3601, 0.5365, 1.1134]], requires_grad=True), Parameter containing:
# tensor([0.3405], requires_grad=True)]
# 22600 6.3752217292785645 [Parameter containing:
# tensor([[0.3601, 0.5365, 1.1134]], requires_grad=True), Parameter containing:
# tensor([0.3404], requires_grad=True)]
# 22700 6.375193119049072 [Parameter containing:
# tensor([[0.3600, 0.5365, 1.1135]], requires_grad=True), Parameter containing:
# tensor([0.3404], requires_grad=True)]
# 22800 6.375171184539795 [Parameter containing:
# tensor([[0.3600, 0.5366, 1.1135]], requires_grad=True), Parameter containing:
# tensor([0.3404], requires_grad=True)]
# 22900 6.375162124633789 [Parameter containing:
# tensor([[0.3600, 0.5366, 1.1135]], requires_grad=True), Parameter containing:
# tensor([0.3404], requires_grad=True)]
# 23000 6.37513542175293 [Parameter containing:
# tensor([[0.3600, 0.5366, 1.1135]], requires_grad=True), Parameter containing:
# tensor([0.3404], requires_grad=True)]
# 23100 6.375126361846924 [Parameter containing:
# tensor([[0.3599, 0.5366, 1.1136]], requires_grad=True), Parameter containing:
# tensor([0.3403], requires_grad=True)]
# 23200 6.3751091957092285 [Parameter containing:
# tensor([[0.3599, 0.5366, 1.1136]], requires_grad=True), Parameter containing:
# tensor([0.3403], requires_grad=True)]
# 23300 6.375085353851318 [Parameter containing:
# tensor([[0.3599, 0.5366, 1.1136]], requires_grad=True), Parameter containing:
# tensor([0.3403], requires_grad=True)]
# 23400 6.375063419342041 [Parameter containing:
# tensor([[0.3598, 0.5366, 1.1136]], requires_grad=True), Parameter containing:
# tensor([0.3403], requires_grad=True)]
# 23500 6.3750481605529785 [Parameter containing:
# tensor([[0.3598, 0.5366, 1.1137]], requires_grad=True), Parameter containing:
# tensor([0.3403], requires_grad=True)]
# 23600 6.3750319480896 [Parameter containing:
# tensor([[0.3598, 0.5366, 1.1137]], requires_grad=True), Parameter containing:
# tensor([0.3403], requires_grad=True)]
# 23700 6.3750081062316895 [Parameter containing:
# tensor([[0.3597, 0.5366, 1.1137]], requires_grad=True), Parameter containing:
# tensor([0.3402], requires_grad=True)]
# 23800 6.374988555908203 [Parameter containing:
# tensor([[0.3597, 0.5366, 1.1137]], requires_grad=True), Parameter containing:
# tensor([0.3402], requires_grad=True)]
# 23900 6.374978542327881 [Parameter containing:
# tensor([[0.3597, 0.5366, 1.1137]], requires_grad=True), Parameter containing:
# tensor([0.3402], requires_grad=True)]
# 24000 6.37495756149292 [Parameter containing:
# tensor([[0.3597, 0.5366, 1.1138]], requires_grad=True), Parameter containing:
# tensor([0.3402], requires_grad=True)]
# 24100 6.374941349029541 [Parameter containing:
# tensor([[0.3596, 0.5366, 1.1138]], requires_grad=True), Parameter containing:
# tensor([0.3402], requires_grad=True)]
# 24200 6.374929428100586 [Parameter containing:
# tensor([[0.3596, 0.5366, 1.1138]], requires_grad=True), Parameter containing:
# tensor([0.3401], requires_grad=True)]
# 24300 6.374897480010986 [Parameter containing:
# tensor([[0.3596, 0.5366, 1.1138]], requires_grad=True), Parameter containing:
# tensor([0.3401], requires_grad=True)]
# 24400 6.374895095825195 [Parameter containing:
# tensor([[0.3595, 0.5366, 1.1139]], requires_grad=True), Parameter containing:
# tensor([0.3401], requires_grad=True)]
# 24500 6.374867916107178 [Parameter containing:
# tensor([[0.3595, 0.5366, 1.1139]], requires_grad=True), Parameter containing:
# tensor([0.3401], requires_grad=True)]
# 24600 6.374849796295166 [Parameter containing:
# tensor([[0.3595, 0.5367, 1.1139]], requires_grad=True), Parameter containing:
# tensor([0.3401], requires_grad=True)]
# 24700 6.374830722808838 [Parameter containing:
# tensor([[0.3594, 0.5367, 1.1139]], requires_grad=True), Parameter containing:
# tensor([0.3401], requires_grad=True)]
# 24800 6.374826908111572 [Parameter containing:
# tensor([[0.3594, 0.5367, 1.1140]], requires_grad=True), Parameter containing:
# tensor([0.3400], requires_grad=True)]
# 24900 6.374805450439453 [Parameter containing:
# tensor([[0.3594, 0.5367, 1.1140]], requires_grad=True), Parameter containing:
# tensor([0.3400], requires_grad=True)]
# 25000 6.374783039093018 [Parameter containing:
# tensor([[0.3594, 0.5367, 1.1140]], requires_grad=True), Parameter containing:
# tensor([0.3400], requires_grad=True)]
# 25100 6.374757766723633 [Parameter containing:
# tensor([[0.3593, 0.5367, 1.1140]], requires_grad=True), Parameter containing:
# tensor([0.3400], requires_grad=True)]
# 25200 6.37474250793457 [Parameter containing:
# tensor([[0.3593, 0.5367, 1.1141]], requires_grad=True), Parameter containing:
# tensor([0.3400], requires_grad=True)]
# 25300 6.374731540679932 [Parameter containing:
# tensor([[0.3593, 0.5367, 1.1141]], requires_grad=True), Parameter containing:
# tensor([0.3400], requires_grad=True)]
# 25400 6.374706745147705 [Parameter containing:
# tensor([[0.3592, 0.5367, 1.1141]], requires_grad=True), Parameter containing:
# tensor([0.3399], requires_grad=True)]
# 25500 6.374691009521484 [Parameter containing:
# tensor([[0.3592, 0.5367, 1.1141]], requires_grad=True), Parameter containing:
# tensor([0.3399], requires_grad=True)]
# 25600 6.374683380126953 [Parameter containing:
# tensor([[0.3592, 0.5367, 1.1142]], requires_grad=True), Parameter containing:
# tensor([0.3399], requires_grad=True)]
# 25700 6.374660491943359 [Parameter containing:
# tensor([[0.3592, 0.5367, 1.1142]], requires_grad=True), Parameter containing:
# tensor([0.3399], requires_grad=True)]
# 25800 6.374642848968506 [Parameter containing:
# tensor([[0.3591, 0.5367, 1.1142]], requires_grad=True), Parameter containing:
# tensor([0.3399], requires_grad=True)]
# 25900 6.374632358551025 [Parameter containing:
# tensor([[0.3591, 0.5367, 1.1142]], requires_grad=True), Parameter containing:
# tensor([0.3398], requires_grad=True)]
# 26000 6.374612331390381 [Parameter containing:
# tensor([[0.3591, 0.5367, 1.1142]], requires_grad=True), Parameter containing:
# tensor([0.3398], requires_grad=True)]
# 26100 6.374608516693115 [Parameter containing:
# tensor([[0.3590, 0.5367, 1.1143]], requires_grad=True), Parameter containing:
# tensor([0.3398], requires_grad=True)]
# 26200 6.374582290649414 [Parameter containing:
# tensor([[0.3590, 0.5367, 1.1143]], requires_grad=True), Parameter containing:
# tensor([0.3398], requires_grad=True)]
# 26300 6.374560832977295 [Parameter containing:
# tensor([[0.3590, 0.5367, 1.1143]], requires_grad=True), Parameter containing:
# tensor([0.3398], requires_grad=True)]
# 26400 6.374556064605713 [Parameter containing:
# tensor([[0.3590, 0.5367, 1.1143]], requires_grad=True), Parameter containing:
# tensor([0.3398], requires_grad=True)]
# 26500 6.3745245933532715 [Parameter containing:
# tensor([[0.3589, 0.5367, 1.1144]], requires_grad=True), Parameter containing:
# tensor([0.3397], requires_grad=True)]
# 26600 6.374520778656006 [Parameter containing:
# tensor([[0.3589, 0.5367, 1.1144]], requires_grad=True), Parameter containing:
# tensor([0.3397], requires_grad=True)]
# 26700 6.3744964599609375 [Parameter containing:
# tensor([[0.3589, 0.5367, 1.1144]], requires_grad=True), Parameter containing:
# tensor([0.3397], requires_grad=True)]
# 26800 6.37449312210083 [Parameter containing:
# tensor([[0.3589, 0.5367, 1.1144]], requires_grad=True), Parameter containing:
# tensor([0.3397], requires_grad=True)]
# 26900 6.374475479125977 [Parameter containing:
# tensor([[0.3588, 0.5367, 1.1145]], requires_grad=True), Parameter containing:
# tensor([0.3397], requires_grad=True)]
# 27000 6.37445068359375 [Parameter containing:
# tensor([[0.3588, 0.5367, 1.1145]], requires_grad=True), Parameter containing:
# tensor([0.3396], requires_grad=True)]
# 27100 6.374440670013428 [Parameter containing:
# tensor([[0.3588, 0.5367, 1.1145]], requires_grad=True), Parameter containing:
# tensor([0.3396], requires_grad=True)]
# 27200 6.374427795410156 [Parameter containing:
# tensor([[0.3588, 0.5367, 1.1145]], requires_grad=True), Parameter containing:
# tensor([0.3396], requires_grad=True)]
# 27300 6.374411106109619 [Parameter containing:
# tensor([[0.3587, 0.5367, 1.1146]], requires_grad=True), Parameter containing:
# tensor([0.3396], requires_grad=True)]
# 27400 6.374391078948975 [Parameter containing:
# tensor([[0.3587, 0.5367, 1.1146]], requires_grad=True), Parameter containing:
# tensor([0.3396], requires_grad=True)]
# 27500 6.374377727508545 [Parameter containing:
# tensor([[0.3587, 0.5368, 1.1146]], requires_grad=True), Parameter containing:
# tensor([0.3396], requires_grad=True)]
# 27600 6.374362468719482 [Parameter containing:
# tensor([[0.3586, 0.5368, 1.1146]], requires_grad=True), Parameter containing:
# tensor([0.3395], requires_grad=True)]
# 27700 6.3743510246276855 [Parameter containing:
# tensor([[0.3586, 0.5368, 1.1147]], requires_grad=True), Parameter containing:
# tensor([0.3395], requires_grad=True)]
# 27800 6.374327182769775 [Parameter containing:
# tensor([[0.3586, 0.5368, 1.1147]], requires_grad=True), Parameter containing:
# tensor([0.3395], requires_grad=True)]
# 27900 6.374321460723877 [Parameter containing:
# tensor([[0.3586, 0.5368, 1.1147]], requires_grad=True), Parameter containing:
# tensor([0.3395], requires_grad=True)]
# 28000 6.374296188354492 [Parameter containing:
# tensor([[0.3585, 0.5368, 1.1147]], requires_grad=True), Parameter containing:
# tensor([0.3395], requires_grad=True)]
# 28100 6.374287128448486 [Parameter containing:
# tensor([[0.3585, 0.5368, 1.1147]], requires_grad=True), Parameter containing:
# tensor([0.3394], requires_grad=True)]
# 28200 6.374268054962158 [Parameter containing:
# tensor([[0.3585, 0.5368, 1.1148]], requires_grad=True), Parameter containing:
# tensor([0.3394], requires_grad=True)]
# 28300 6.37425422668457 [Parameter containing:
# tensor([[0.3585, 0.5368, 1.1148]], requires_grad=True), Parameter containing:
# tensor([0.3394], requires_grad=True)]
# 28400 6.374231338500977 [Parameter containing:
# tensor([[0.3584, 0.5368, 1.1148]], requires_grad=True), Parameter containing:
# tensor([0.3394], requires_grad=True)]
# 28500 6.374222278594971 [Parameter containing:
# tensor([[0.3584, 0.5368, 1.1148]], requires_grad=True), Parameter containing:
# tensor([0.3394], requires_grad=True)]
# 28600 6.374200820922852 [Parameter containing:
# tensor([[0.3584, 0.5368, 1.1149]], requires_grad=True), Parameter containing:
# tensor([0.3394], requires_grad=True)]
# 28700 6.3741936683654785 [Parameter containing:
# tensor([[0.3584, 0.5368, 1.1149]], requires_grad=True), Parameter containing:
# tensor([0.3393], requires_grad=True)]
# 28800 6.374174118041992 [Parameter containing:
# tensor([[0.3583, 0.5368, 1.1149]], requires_grad=True), Parameter containing:
# tensor([0.3393], requires_grad=True)]
# 28900 6.374159336090088 [Parameter containing:
# tensor([[0.3583, 0.5368, 1.1149]], requires_grad=True), Parameter containing:
# tensor([0.3393], requires_grad=True)]
# 29000 6.374148845672607 [Parameter containing:
# tensor([[0.3583, 0.5368, 1.1150]], requires_grad=True), Parameter containing:
# tensor([0.3393], requires_grad=True)]
# 29100 6.3741278648376465 [Parameter containing:
# tensor([[0.3582, 0.5368, 1.1150]], requires_grad=True), Parameter containing:
# tensor([0.3393], requires_grad=True)]
# 29200 6.374112606048584 [Parameter containing:
# tensor([[0.3582, 0.5368, 1.1150]], requires_grad=True), Parameter containing:
# tensor([0.3393], requires_grad=True)]
# 29300 6.374105453491211 [Parameter containing:
# tensor([[0.3582, 0.5368, 1.1150]], requires_grad=True), Parameter containing:
# tensor([0.3392], requires_grad=True)]
# 29400 6.37408447265625 [Parameter containing:
# tensor([[0.3582, 0.5368, 1.1151]], requires_grad=True), Parameter containing:
# tensor([0.3392], requires_grad=True)]
# ...
# tensor([0.3104], requires_grad=True)]
# 190400 6.36703634262085 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3104], requires_grad=True)]
# 190500 6.367040634155273 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3104], requires_grad=True)]
# 190600 6.367027759552002 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3104], requires_grad=True)]
# 190700 6.367033004760742 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3104], requires_grad=True)]
# 190800 6.367028713226318 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3104], requires_grad=True)]
# 190900 6.367016315460205 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3103], requires_grad=True)]
# 191000 6.3670196533203125 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3103], requires_grad=True)]
# 191100 6.367008209228516 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3103], requires_grad=True)]
# 191200 6.367013931274414 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3103], requires_grad=True)]
# 191300 6.367002487182617 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3103], requires_grad=True)]
# 191400 6.367006301879883 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3102], requires_grad=True)]
# 191500 6.367006778717041 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3102], requires_grad=True)]
# 191600 6.36699914932251 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3102], requires_grad=True)]
# 191700 6.366990566253662 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3102], requires_grad=True)]
# 191800 6.366994857788086 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3102], requires_grad=True)]
# 191900 6.366998672485352 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3102], requires_grad=True)]
# 192000 6.367001056671143 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3101], requires_grad=True)]
# 192100 6.366979122161865 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3101], requires_grad=True)]
# 192200 6.366984844207764 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3101], requires_grad=True)]
# 192300 6.366971969604492 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3101], requires_grad=True)]
# 192400 6.366964817047119 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3101], requires_grad=True)]
# 192500 6.366970062255859 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3101], requires_grad=True)]
# 192600 6.366964340209961 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3100], requires_grad=True)]
# 192700 6.366959095001221 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3100], requires_grad=True)]
# 192800 6.366954803466797 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3100], requires_grad=True)]
# 192900 6.366954803466797 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3100], requires_grad=True)]
# 193000 6.366952419281006 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3100], requires_grad=True)]
# 193100 6.366958141326904 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3099], requires_grad=True)]
# 193200 6.366945743560791 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3099], requires_grad=True)]
# 193300 6.36694860458374 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3099], requires_grad=True)]
# 193400 6.366941452026367 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3099], requires_grad=True)]
# 193500 6.36693811416626 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3099], requires_grad=True)]
# 193600 6.366935729980469 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3099], requires_grad=True)]
# 193700 6.366926193237305 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3098], requires_grad=True)]
# 193800 6.366924285888672 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3098], requires_grad=True)]
# 193900 6.366924285888672 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3098], requires_grad=True)]
# 194000 6.3669281005859375 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3098], requires_grad=True)]
# 194100 6.366919040679932 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3098], requires_grad=True)]
# 194200 6.36692476272583 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3097], requires_grad=True)]
# 194300 6.366909027099609 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3097], requires_grad=True)]
# 194400 6.366909027099609 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3097], requires_grad=True)]
# 194500 6.36690092086792 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3097], requires_grad=True)]
# 194600 6.366899490356445 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3097], requires_grad=True)]
# 194700 6.36690092086792 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3097], requires_grad=True)]
# 194800 6.366896152496338 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3096], requires_grad=True)]
# 194900 6.366899490356445 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3096], requires_grad=True)]
# 195000 6.36688756942749 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3096], requires_grad=True)]
# 195100 6.366892337799072 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3096], requires_grad=True)]
# 195200 6.366889953613281 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3096], requires_grad=True)]
# 195300 6.366881847381592 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3096], requires_grad=True)]
# 195400 6.3668742179870605 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3095], requires_grad=True)]
# 195500 6.366880416870117 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3095], requires_grad=True)]
# 195600 6.366865634918213 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3095], requires_grad=True)]
# 195700 6.3668646812438965 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3095], requires_grad=True)]
# 195800 6.366858005523682 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3095], requires_grad=True)]
# 195900 6.366870403289795 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3094], requires_grad=True)]
# 196000 6.366856098175049 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3094], requires_grad=True)]
# 196100 6.366854190826416 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3094], requires_grad=True)]
# 196200 6.366851806640625 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3094], requires_grad=True)]
# 196300 6.366846561431885 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3094], requires_grad=True)]
# 196400 6.366842746734619 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3094], requires_grad=True)]
# 196500 6.3668389320373535 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3093], requires_grad=True)]
# 196600 6.366830825805664 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3093], requires_grad=True)]
# 196700 6.36683988571167 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3093], requires_grad=True)]
# 196800 6.366837978363037 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3093], requires_grad=True)]
# 196900 6.36682653427124 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3093], requires_grad=True)]
# 197000 6.366828918457031 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3092], requires_grad=True)]
# 197100 6.366823196411133 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3092], requires_grad=True)]
# 197200 6.366816997528076 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3092], requires_grad=True)]
# 197300 6.366819381713867 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3092], requires_grad=True)]
# 197400 6.366816997528076 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3092], requires_grad=True)]
# 197500 6.36680269241333 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3092], requires_grad=True)]
# 197600 6.3668060302734375 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3091], requires_grad=True)]
# 197700 6.366804599761963 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3091], requires_grad=True)]
# 197800 6.366794586181641 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3091], requires_grad=True)]
# 197900 6.366796016693115 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3091], requires_grad=True)]
# 198000 6.366796970367432 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3091], requires_grad=True)]
# 198100 6.366790771484375 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3091], requires_grad=True)]
# 198200 6.366787433624268 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3090], requires_grad=True)]
# 198300 6.366786956787109 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3090], requires_grad=True)]
# 198400 6.366774082183838 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3090], requires_grad=True)]
# 198500 6.366783618927002 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3090], requires_grad=True)]
# 198600 6.366776943206787 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3090], requires_grad=True)]
# 198700 6.366779804229736 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3089], requires_grad=True)]
# 198800 6.366763591766357 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3089], requires_grad=True)]
# 198900 6.366756916046143 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3089], requires_grad=True)]
# 199000 6.366764068603516 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3089], requires_grad=True)]
# 199100 6.366756439208984 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3089], requires_grad=True)]
# 199200 6.36676025390625 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3089], requires_grad=True)]
# 199300 6.366743087768555 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3088], requires_grad=True)]
# 199400 6.366758823394775 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3088], requires_grad=True)]
# 199500 6.3667449951171875 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3088], requires_grad=True)]
# 199600 6.36674165725708 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3088], requires_grad=True)]
# 199700 6.366736888885498 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3088], requires_grad=True)]
# 199800 6.3667378425598145 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3087], requires_grad=True)]
# 199900 6.366736888885498 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3087], requires_grad=True)]
# 200000 6.36672830581665 [Parameter containing:
# tensor([[0.3500, 0.5397, 1.1205]], requires_grad=True), Parameter containing:
# tensor([0.3087], requires_grad=True)]

# %% [markdown]
# # 생성된 모델로 예측하기

# %%
x = torch.FloatTensor([[75,85,90],[90,85,75]])
model(x)
# Out:
# tensor([[173.2812],
#         [161.7227]], grad_fn=<AddmmBackward0>)
